# %% [markdown]
# <a href="https://colab.research.google.com/github/Liliya-Gatina/Homeworks/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.

# %%
import math
x=float(input('x='))
if 0<=x<=3:
  f=x**2
else:
  f=4+math.pow(x, 1/3)
print(f)
# Out:
# x=3
# 9.0

# %% [markdown]
# 2.

# %%
n=int(input())
a=n//100
b=(n//10)%10
c=n%10
S=a+b+c
y=S%2==0
print(y)
# Out:
# 121
# True

# %% [markdown]
# 3.

# %%
a = float(input())
b = float(input())
c = float(input())
if (a + b > c and a + c > b and b + c > a):
    p = (a + b + c) / 2
    s = (p * (p - a) * (p - b) * (p - c)) ** 0.5
    print(f"{s:.2f}")
else:
    print("Эти числа не являются сторонами треугольника")
# Out:
# 13
# 5
# 12
# 30.00

# %% [markdown]
# 4.

# %%
a=int(input('a='))
b=int(input('b='))
c=int(input('c='))
d=int(input('d='))
if a/b/c/d:
  print('Меньший ток протекает через второй участок')
else:
  print('Ток одинаков на обоих участках')
# Out:
# a=3
# b=4
# c=5
# d=3
# Меньший ток протекает через второй участок

# %% [markdown]
# 5.

# %%
m = int(input('m'))
n = int(input('n'))

if n == 1:
    if m == 1:
        prev_m, prev_n = 12, 31
    elif m == 4 or m == 6 or m == 9 or m == 11:
        prev_m, prev_n = m - 1, 30
    elif m == 2:
        prev_m, prev_n = 1, 28
    else:
        prev_m, prev_n = m - 1, 31
else:
    prev_m, prev_n = m, n - 1

if m == 1 or m == 3 or m == 5 or m == 7 or m == 8 or m == 10 or m == 12:
    days_in_month = 31
elif m == 2:
    days_in_month = 28
else:
    days_in_month = 30

if n == days_in_month:
    if m == 12:
        next_m, next_n = 1, 1
    else:
        next_m, next_n = m + 1, 1
else:
    next_m, next_n = m, n + 1

print(prev_m, prev_n)
print(next_m, next_n)
# Out:
# m3
# n15
# 3 14
# 3 16

# %%
m = int(input('m='))
n = int(input('n='))
1<=m<=12
1<=n<=31
m!=12 and n!=31
m!=1 and n!=1
print(m, n+1)
print(m, n-1)
# Out:
# m=12
# n=31
# 12 32
# 12 30
